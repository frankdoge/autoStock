# %%
import tushare as ts

# %%
from jqdatasdk import *
auth('15707956978','CSUbigdata123')
logout()
# Out:
# 已退出

# %%
get_all_securities(['stock'])
# Out:
#             display_name   name start_date   end_date   type
# 000001.XSHE         平安银行   PAYH 1991-04-03 2200-01-01  stock
# 000002.XSHE          万科A    WKA 1991-01-29 2200-01-01  stock
# 000004.XSHE         国华网安   GHWA 1990-12-01 2200-01-01  stock
# 000005.XSHE         ST星源   STXY 1990-12-10 2200-01-01  stock
# 000006.XSHE         深振业A   SZYA 1992-04-27 2200-01-01  stock
# 000007.XSHE        *ST全新  *STQX 1992-04-13 2200-01-01  stock
# 000008.XSHE         神州高铁   SZGT 1992-05-07 2200-01-01  stock
# 000009.XSHE         中国宝安   ZGBA 1991-06-25 2200-01-01  stock
# 000010.XSHE         美丽生态   MLST 1995-10-27 2200-01-01  stock
# 000011.XSHE         深物业A   SWYA 1992-03-30 2200-01-01  stock
# 000012.XSHE          南玻A    NBA 1992-02-28 2200-01-01  stock
# 000014.XSHE         沙河股份   SHGF 1992-06-02 2200-01-01  stock
# 000016.XSHE         深康佳A   SKJA 1992-03-27 2200-01-01  stock
# 000017.XSHE         深中华A   SZHA 1992-03-31 2200-01-01  stock
# ...

# %%
import time

# %%
def all_security_list():
    df2 = get_all_securities(['stock'])
    list1 = list(df2.index)
    df1 = get_price(list1,None,'2023-03-22','daily','close',True,'pre',count=1,panel=False,fill_paused=True)
    df1['name'] = df2.loc[list(df1['code'])].display_name.values
    return df1.to_json(orient="records")

# %%
def all_security_list1():
    data = pro.stock_basic(exchange='',list_status='L',fields='ts_code,symbol,name,area,industry,list_date')

# %%
all_security_list()
# Out:
# '[{"time":1679443200000,"code":"002233.XSHE","close":7.7,"name":"\\u5854\\u724c\\u96c6\\u56e2"},{"time":1679443200000,"code":"301306.XSHE","close":45.61,"name":"\\u897f\\u6d4b\\u6d4b\\u8bd5"},{"time":1679443200000,"code":"603809.XSHG","close":11.36,"name":"\\u8c6a\\u80fd\\u80a1\\u4efd"},{"time":1168300800000,"code":"600205.XSHG","close":25.41,"name":"S\\u5c71\\u4e1c\\u94dd"},{"time":1679443200000,"code":"002897.XSHE","close":47.99,"name":"\\u610f\\u534e\\u80a1\\u4efd"},{"time":1679443200000,"code":"002906.XSHE","close":32.43,"name":"\\u534e\\u9633\\u96c6\\u56e2"},{"time":1679443200000,"code":"002596.XSHE","close":3.68,"name":"\\u6d77\\u5357\\u745e\\u6cfd"},{"time":1679443200000,"code":"300846.XSHE","close":14.1,"name":"\\u9996\\u90fd\\u5728\\u7ebf"},{"time":1679443200000,"code":"600387.XSHG","close":6.85,"name":"ST\\u6d77\\u8d8a"},{"time":1679443200000,"code":"688190.XSHG","close":80.77,"name":"\\u4e91\\u8def\\u80a1\\u4efd"},{"time":1679443200000,"code":"688213.XSHG","close":47.4,"na
# ...

# %%
ts.set_token('ebd374898a15c69a938b0b6c2de6beb2854b694a4bbe6c731640bfc4')

# %%
pro = ts.pro_api()

# %%
df = pro.daily(ts_code='000001.sz',start_date='20230825',end_date='20230901')

# %%
data = pro.stock_basic(exchange='',list_status='L',fields='ts_code,symbol,name,area,industry,list_date')

# %%
list(data.ts_code)
# Out:
# ['000001.SZ',
#  '000002.SZ',
#  '000004.SZ',
#  '000005.SZ',
#  '000006.SZ',
#  '000007.SZ',
#  '000008.SZ',
#  '000009.SZ',
#  '000010.SZ',
#  '000011.SZ',
#  '000012.SZ',
#  '000014.SZ',
#  '000016.SZ',
#  '000017.SZ',
#  '000019.SZ',
#  '000020.SZ',
#  '000021.SZ',
#  '000023.SZ',
#  '000025.SZ',
#  '000026.SZ',
#  '000027.SZ',
#  '000028.SZ',
#  '000029.SZ',
#  '000030.SZ',
#  '000031.SZ',
#  '000032.SZ',
#  '000034.SZ',
#  '000035.SZ',
#  '000036.SZ',
#  '000037.SZ',
#  '000039.SZ',
#  '000040.SZ',
#  '000042.SZ',
#  '000045.SZ',
#  '000046.SZ',
#  '000048.SZ',
#  '000049.SZ',
#  '000050.SZ',
#  '000055.SZ',
#  '000056.SZ',
#  '000058.SZ',
#  '000059.SZ',
#  '000060.SZ',
#  '000061.SZ',
#  '000062.SZ',
#  '000063.SZ',
#  '000065.SZ',
#  '000066.SZ',
#  '000068.SZ',
#  '000069.SZ',
#  '000070.SZ',
#  '000078.SZ',
#  '000088.SZ',
#  '000089.SZ',
#  '000090.SZ',
#  '000096.SZ',
#  '000099.SZ',
#  '000100.SZ',
#  '000151.SZ',
#  '000153.SZ',
#  '000155.SZ',
#  '000156.SZ',
# ...

# %%
list1 = list(data.ts_code)[:50]

# %%
longstr='000001.SZ'
for i in range(1,len(list1)):
    longstr = longstr+','+list1[i]

# %%
longstr
# Out:
# '000001.SZ,000002.SZ,000004.SZ,000005.SZ,000006.SZ,000007.SZ,000008.SZ,000009.SZ,000010.SZ,000011.SZ,000012.SZ,000014.SZ,000016.SZ,000017.SZ,000019.SZ,000020.SZ,000021.SZ,000023.SZ,000025.SZ,000026.SZ,000027.SZ,000028.SZ,000029.SZ,000030.SZ,000031.SZ,000032.SZ,000034.SZ,000035.SZ,000036.SZ,000037.SZ,000039.SZ,000040.SZ,000042.SZ,000045.SZ,000046.SZ,000048.SZ,000049.SZ,000050.SZ,000055.SZ,000056.SZ,000058.SZ,000059.SZ,000060.SZ,000061.SZ,000062.SZ,000063.SZ,000065.SZ,000066.SZ,000068.SZ,000069.SZ'

# %%
df = pro.daily(ts_code=longstr,start_date='20230823',end_date='20230823')

# %%
df
# Out:
#       ts_code trade_date   open   high    low  close  pre_close  change  \
# 0   000055.SZ   20230823   4.94   4.95   4.88   4.89       4.94   -0.05
# 1   000034.SZ   20230823  29.80  32.00  29.79  30.73      30.33    0.40
# 2   000035.SZ   20230823   5.40   5.46   5.30   5.34       5.40   -0.06
# 3   000036.SZ   20230823   4.10   4.12   4.02   4.03       4.08   -0.05
# 4   000037.SZ   20230823   9.69   9.83   9.56   9.59       9.75   -0.16
# 5   000039.SZ   20230823   7.06   7.12   7.01   7.06       7.06    0.00
# 6   000040.SZ   20230823   4.05   4.05   3.98   3.98       4.06   -0.08
# 7   000042.SZ   20230823   7.72   7.77   7.58   7.60       7.77   -0.17
# 8   000045.SZ   20230823   9.76   9.91   9.61   9.71       9.78   -0.07
# 9   000046.SZ   20230823   1.82   1.86   1.76   1.76       1.85   -0.09
# 10  000048.SZ   20230823  18.92  19.12  18.70  18.72      19.04   -0.32
# 11  000049.SZ   20230823  30.35  30.35  29.36  29.36      30.36   -1.00
# ...

# %%
data.ts_code
# Out:
# 0       000001.SZ
# 1       000002.SZ
# 2       000004.SZ
# 3       000005.SZ
# 4       000006.SZ
# 5       000007.SZ
# 6       000008.SZ
# 7       000009.SZ
# 8       000010.SZ
# 9       000011.SZ
# 10      000012.SZ
# 11      000014.SZ
# 12      000016.SZ
# 13      000017.SZ
# 14      000019.SZ
# 15      000020.SZ
# 16      000021.SZ
# 17      000023.SZ
# 18      000025.SZ
# 19      000026.SZ
# 20      000027.SZ
# 21      000028.SZ
# 22      000029.SZ
# 23      000030.SZ
# 24      000031.SZ
# 25      000032.SZ
# 26      000034.SZ
# 27      000035.SZ
# 28      000036.SZ
# 29      000037.SZ
#           ...
# 5238    871478.BJ
# 5239    871553.BJ
# 5240    871634.BJ
# 5241    871642.BJ
# 5242    871694.BJ
# 5243    871753.BJ
# 5244    871857.BJ
# 5245    871970.BJ
# 5246    871981.BJ
# 5247    872190.BJ
# 5248    872351.BJ
# 5249    872374.BJ
# 5250    872392.BJ
# 5251    872541.BJ
# 5252    872808.BJ
# 5253    872895.BJ
# 5254    872925.BJ
# 5255    872953.BJ
# 5256    873001.BJ
# ...

# %%
def MADF(md1:int, md2:int):
    df2 = get_all_securities(['stock'])
    list1 = list(df2.index)
    df1 = get_price(list1,None,'2023-04-23','daily','close',True,'pre',count=5,panel=False,fill_paused=True)
    list2 = [df1.iloc[i + 1, 1] for i in range(0, df1.shape[0], 10) if df1.iloc[i : i + md1 - 1, 2].mean() > df1.iloc[i : i + md2 - 1, 2].mean()]
    df3 = get_price(list2,None,'2023-04-23','daily','close',True,'pre',count=1,panel=False,fill_paused=True)
    df3['name'] = df2.loc[list(df3['code'])].display_name.values
    return df3.to_json(orient="records")

# %%
MADF(1,5)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-56-c8ebc55e9cca> in <module>
# ----> 1 MADF(1,5)
#
# <ipython-input-54-f808e85b4bd8> in MADF(md1, md2)
#       4     df1 = get_price(list1,None,'2023-04-23','daily','close',True,'pre',count=5,panel=False,fill_paused=True)
#       5     list2 = [df1.iloc[i + 1, 1] for i in range(0, df1.shape[0], 10) if df1.iloc[i : i + md1 - 1, 2].mean() > df1.iloc[i : i + md2 - 1, 2].mean()]
# ----> 6     df3 = get_price(list2,None,'2023-04-23','daily','close',True,'pre',count=1,panel=False,fill_paused=True)
#       7     df3['name'] = df2.loc[list(df3['code'])].display_name.values
#       8     return df3.to_json(orient="records")
#
# c:\Users\lihan\.conda\envs\bigdata\lib\site-packages\jqdatasdk\utils.py in _wrapper(*args, **kwargs)
#     254             print("run jqdatasdk.auth first")
#     255         else:
# ...
