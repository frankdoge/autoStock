# %%
'''
 ┌─────────────────────────────────────────────────────────────┐
 │┌───┬───┬───┬───┬───┬───┬───┬───┬───┬───┬───┬───┬───┬───┬───┐│
 ││Esc│!1 │@2 │#3 │$4 │%5 │^6 │&7 │*8 │(9 │)0 │_- │+= │|\ │`~ ││
 │├───┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴───┤│
 ││ Tab │ Q │ W │ E │ R │ T │ Y │ U │ I │ O │ P │{[ │}] │ BS  ││
 │├─────┴┬──┴┬──┴┬──┴┬──┴┬──┴┬──┴┬──┴┬──┴┬──┴┬──┴┬──┴┬──┴─────┤│
 ││ Ctrl │ A │ S │ D │ F │ G │ H │ J │ K │ L │: ;│" '│ Enter  ││
 │├──────┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴─┬─┴────┬───┤│
 ││ Shift  │ Z │ X │ C │ V │ B │ N │ M │< ,│> .│? /│Shift │Fn ││
 │└─────┬──┴┬──┴──┬┴───┴───┴───┴───┴───┴──┬┴───┴┬──┴┬─────┴───┘│
 │      │Fn │ Alt │         Space         │ Alt │Win│   HHKB   │
 │      └───┴─────┴───────────────────────┴─────┴───┘          │
 └─────────────────────────────────────────────────────────────┘

Description  : 
Author       : 嘉恒
LastEditors  : 嘉恒 jhincs@csu.edu.cn
Date         : 2022-05-26 10:26:35
LastEditTime : 2022-05-29 15:31:09
FilePath     : \quant\strategy_template.ipynb
'''
import easyquotation
import easytrader 
import warnings
warnings.simplefilter('ignore', category=UserWarning)
# from apscheduler.schedulers.blocking import BackgroundScheduler
import pandas as pd
from datetime import datetime
import time
import os
from jqdatasdk import *
auth('18974988801','Bigdata12345678')
# Out:
# auth success

# %%
def all_security_list():
    df2 = get_all_securities(['stock'])
    list1 = list(df2.index)
    df1 = get_price(list1,None,time.strftime("%Y-%m-%d", time.localtime()),'daily','close',True,'pre',count=1,panel=False,fill_paused=True)
    df1['name'] = df2.loc[list(df1['code'])].display_name.values
    return df1

# %%
def MADF(md1:int, md2:int):
    df2 = get_all_securities(['stock'])
    list1 = list(df2.index)
    df1 = get_price(list1,None,time.strftime("%Y-%m-%d", time.localtime()),'daily','close',True,'pre',count=md2,panel=False,fill_paused=True)
    list2 = [df1.iloc[i + 1, 1] for i in range(0, df1.shape[0], 10) if df1.iloc[i : i + md1 - 1, 2].mean() > df1.iloc[i : i + md2 - 1, 2].mean()]
    df3 = get_price(list2,None,time.strftime("%Y-%m-%d", time.localtime()),'daily','close',True,'pre',count=1,panel=False,fill_paused=True)
    df3['name'] = df2.loc[list(df3['code'])].display_name.values
    return df3

# %%
MADF(5,10)
# Out:
#            time         code   close  name
# 0    2022-07-19  002233.XSHE    8.34  塔牌集团
# 1    2022-07-19  603809.XSHG   13.39  豪能股份
# 2    2022-07-19  002919.XSHE   18.62  名臣健康
# 3    2022-07-19  605218.XSHG   12.91  伟时电子
# 4    2022-07-19  300846.XSHE   12.76  首都在线
# 5    2022-07-19  600844.XSHG    3.13  丹化科技
# 6    2022-07-19  301048.XSHE   11.10  金鹰重工
# 7    2022-07-19  601229.XSHG    6.00  上海银行
# 8    2022-07-19  000988.XSHE   22.51  华工科技
# 9    2022-07-19  300812.XSHE   18.57  易天股份
# 10   2022-07-19  002296.XSHE    7.36  辉煌科技
# 11   2022-07-19  300033.XSHE   88.81   同花顺
# 12   2022-07-19  002858.XSHE   10.92  力盛体育
# 13   2022-07-19  000949.XSHE    3.48  新乡化纤
# 14   2022-07-19  301211.XSHE   21.36  亨迪药业
# 15   2022-07-19  002610.XSHE    3.86  爱康科技
# 16   2022-07-19  002562.XSHE    6.99  兄弟科技
# 17   2022-07-19  603089.XSHG    8.71  正裕工业
# 18   2022-07-19  301081.XSHE   15.68  严牌股份
# 19   2022-07-19  300843.XSHE   23.76  胜蓝股份
# 20   2022-07-19  300631.XSHE   29.45  久吾高科
# 21   2022-07-19  600682.XSHG    9.80  南京新百
# 22   2022-07-19  603912.XSHG   11.15   佳力图
# 23   2022-07-19  300986.XSHE   32.59  志特新材
# 24   2022-07-19  603536.XSHG    7.10  惠发食品
# 25   2022-07-19  002375.XSHE    5.05  亚厦股份
# 26   2022-07-19  002092.XSHE    7.49  中泰化学
# 27   2022-07-19  301009.XSHE   11.97  可靠股份
# 28   2022-07-19  601155.XSHG   20.85  新城控股
# 29   2022-07-19  001219.XSHE   20.80  青岛食品
# ...         ...          ...     ...   ...
# 3227 2022-07-19  000858.XSHE  188.90   五粮液
# 3228 2022-07-19  600826.XSHG    7.51  兰生股份
# 3229 2022-06-30  600385.XSHG    1.20  退市金泰
# 3230 2022-07-19  300700.XSHE   27.91  岱勒新材
# 3231 2022-07-19  688238.XSHG   28.52  和元生物
# 3232 2022-07-19  603180.XSHG   25.81  金牌厨柜
# 3233 2022-07-19  601020.XSHG   13.60  华钰矿业
# 3234 2022-07-19  600216.XSHG   14.49  浙江医药
# 3235 2022-07-19  300243.XSHE    9.98  瑞丰高材
# 3236 2022-07-19  001212.XSHE   35.51  中旗新材
# 3237 2022-07-19  002102.XSHE    3.44  ST冠福
# 3238 2022-07-19  000868.XSHE    6.58  安凯客车
# 3239 2022-07-19  301302.XSHE   66.40  华如科技
# 3240 2022-07-19  600299.XSHG    9.59   安迪苏
# 3241 2022-07-19  301006.XSHE   19.05  迈拓股份
# 3242 2022-07-19  603655.XSHG   18.87  朗博科技
# 3243 2022-07-19  600862.XSHG   26.29  中航高科
# 3244 2022-07-19  301190.XSHE   23.29  善水科技
# 3245 2022-07-19  603508.XSHG   13.44  思维列控
# 3246 2022-07-19  300209.XSHE    8.39  天泽信息
# 3247 2022-07-19  603662.XSHG   15.43  柯力传感
# 3248 2022-07-19  002795.XSHE    8.13  永和智控
# 3249 2022-07-19  000622.XSHE    4.75  恒立实业
# 3250 2022-07-19  600511.XSHG   26.47  国药股份
# 3251 2022-07-19  603068.XSHG   33.86  博通集成
# 3252 2022-07-19  000070.XSHE    6.73  特发信息
# 3253 2022-07-19  603392.XSHG  144.20  万泰生物
# 3254 2022-07-19  605199.XSHG   17.18   葫芦娃
# 3255 2022-07-19  688182.XSHG   14.19  灿勤科技
# 3256 2022-07-19  002130.XSHE    6.35  沃尔核材
#
# [3257 rows x 4 columns]

# %%
'''
description: 定义获取数据的地址，设定交易系统，并且打开交易系统界面。
return {None}
'''
quotation = easyquotation.use('sina')#使用新浪获取数据
bigdata1 = easytrader.use('universal_client')#定义使用universal_client

# %%
bigdata1.prepare(user='027000055542', comm_password='199707',exe_path=r'd:\\ths\\xiadan.exe')
# Out:
# e:\code\teste\apis\lib\site-packages\pywinauto\application.py:1064: UserWarning: 32-bit application should be automated using 32-bit Python (you use 64-bit Python)
#   UserWarning)

# %%
bigdata1.today_trades
# Out:
# []

# %%
bigdata1.buy()

# %%
bigdata1.balance
# Out:
# {'资金余额': 6048.58, '可用金额': 6048.58, '可取金额': 6048.58, '总资产': 6048.58}

# %%
try:
    bigdata1.prepare(user='027000055542', comm_password='199707',exe_path=r'd:\\ths\\xiadan.exe')
except Exception:
    bigdata1.prepare(user='027000055542', comm_password='199707',exe_path=r'd:\\ths\\xiadan.exe')

# %%
'''
description: 写入一些工具函数
'''
def get_security_num(security:str) -> str:
    """ 
        因为聚宽的股票数据使用字段为600001.XSHE
        与easyquotation的600001有区别因此使用函数进行转换
        
    Args:
        security: 聚宽要求的stock代码字段

    Returns:
        str:easyquotation要求的股票字段
    """    
    return "".join(list(filter(str.isdigit,security)))

# %%
position = bigdata1.position

# %%
position
# Out:
# []

# %%
template

# %%
balance
# Out:
# {'资金余额': 5423.39, '可用金额': 5423.39, '可取金额': 5423.39, '总资产': 5423.39}

# %%
bigdata1.buy('000625',17.01,100)
# Out:
# {'entrust_no': '1'}

# %%
def MAlines(security:str,md1:int,md2:int) -> bool:
    m1 = md1
    m2 = md2
    num1 = get_price(
    normalize_code(security),
    end_date=time.strftime("%Y-%m-%d", time.localtime()),
    count=md1,
    frequency='daily',
    fields=['close'],
    panel=False,).mean()
    num2 = get_price(
    normalize_code(security),
    end_date=time.strftime("%Y-%m-%d", time.localtime()),
    count=md2,
    frequency='daily',
    fields=['close'],
    panel=False,).mean()
    if (num1[0]>num2[0]):
        print("可以购买",security,get_security_info(normalize_code(security)),time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
    if (num1[0]<num2[0]):
        print("卖出",security,get_security_info(normalize_code(security)).display_name,time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))

# %%
scheduler = BackgroundScheduler()
scheduler.add_job(MAlines,'interval',kwargs={"security":'002251',"md1":5,"md2":10}, seconds = 10)
print('Press Ctrl+{0} to exit'.format('Break' if os.name == 'nt' else 'C'))
try:
    scheduler.start()
except (KeyboardInterrupt, SystemExit):
    scheduler.shutdown()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e74c4c52a800> in <module>
# ----> 1 scheduler = BackgroundScheduler()
#       2 scheduler.add_job(MAlines,'interval',kwargs={"security":'002251',"md1":5,"md2":10}, seconds = 10)
#       3 print('Press Ctrl+{0} to exit'.format('Break' if os.name == 'nt' else 'C'))
#       4 try:
#       5     scheduler.start()
#
# NameError: name 'BackgroundScheduler' is not defined

# %%
from apscheduler.schedulers.background import BackgroundScheduler
import time

def job():
    print('job 3s')


if __name__=='__main__':

    sched = BackgroundScheduler(timezone='MST')
    sched.add_job(job, 'interval', id='3_second_job', seconds=3)
    sched.start()

    while(True):
        print('main 1s')
        time.sleep(1)
# Out:
# main 1s
# main 1s
# main 1s
# job 3s
# main 1s
# main 1s
# main 1s
# job 3s
# main 1s
# main 1s
# main 1s
# job 3s
# main 1s
# main 1s
# main 1s
# job 3s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-7c2bfd4a353e> in <module>
#      14     while(True):
#      15         print('main 1s')
# ---> 16         time.sleep(1)
#
# KeyboardInterrupt:
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s
# job 3s

# %%
get_security_info(normalize_code('002251')).display_name
# Out:
# '步步高'

# %%
time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
# Out:
# '2022-05-30 21:34:14'

# %%
print("卖出",security,time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2127c8b7ccf3> in <module>
# ----> 1 print("卖出",security,time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
#
# NameError: name 'security' is not defined
